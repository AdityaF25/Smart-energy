# %%
# Import Pandas library for data manipulation and analysis
import pandas as pd  

# Import NumPy library for numerical computations
import numpy as np  

# Import Matplotlib's pyplot module for creating plots and charts
import matplotlib.pyplot as plt  

# Magic command to display Matplotlib plots inline within the Jupyter Notebook
# %matplotlib inline  

# Import Seaborn library for statistical data visualization
import seaborn as sns  

# Import MinMaxScaler and StandardScaler classes for feature scaling
from sklearn.preprocessing import MinMaxScaler, StandardScaler  

# Import datetime class for handling date and time data types
from datetime import datetime  

# Import warnings module to control display of warning messages
import warnings  

# Set the warning filter to ignore all warning messages
warnings.filterwarnings("ignore")

# %%
# Path to the CSV file to be read
df=pd.read_csv(r"C:\Users\Dharshini\OneDrive\Desktop\Home.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503911 entries, 0 to 503910
# Data columns (total 32 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time                 503911 non-null  object
#  1   use [kW]             503910 non-null  float64
#  2   gen [kW]             503910 non-null  float64
#  3   House overall [kW]   503910 non-null  float64
#  4   Dishwasher [kW]      503910 non-null  float64
#  5   Furnace 1 [kW]       503910 non-null  float64
#  6   Furnace 2 [kW]       503910 non-null  float64
#  7   Home office [kW]     503910 non-null  float64
#  8   Fridge [kW]          503910 non-null  float64
#  9   Wine cellar [kW]     503910 non-null  float64
#  10  Garage door [kW]     503910 non-null  float64
#  11  Kitchen 12 [kW]      503910 non-null  float64
#  12  Kitchen 14 [kW]      503910 non-null  float64
#  13  Kitchen 38 [kW]      503910 non-null  float64
# ...

# %%
df.head(10)
# Out:
#          time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0  1451624400  0.932833  0.003483            0.932833         0.000033
# 1  1451624401  0.934333  0.003467            0.934333         0.000000
# 2  1451624402  0.931817  0.003467            0.931817         0.000017
# 3  1451624403  1.022050  0.003483            1.022050         0.000017
# 4  1451624404  1.139400  0.003467            1.139400         0.000133
# 5  1451624405  1.391867  0.003433            1.391867         0.000283
# 6  1451624406  1.366217  0.003450            1.366217         0.000283
# 7  1451624407  1.431900  0.003417            1.431900         0.000250
# 8  1451624408  1.627300  0.003417            1.627300         0.000183
# 9  1451624409  1.735383  0.003417            1.735383         0.000017
#
#    Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# 0        0.020700        0.061917          0.442633     0.124150
# ...

# %%
df.tail(10)
# Out:
#               time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 503901  1452128301  1.537383  0.003183            1.537383         0.000133
# 503902  1452128302  1.551817  0.003200            1.551817         0.000050
# 503903  1452128303  1.599617  0.003217            1.599617         0.000067
# 503904  1452128304  1.608867  0.003217            1.608867         0.000033
# 503905  1452128305  1.601233  0.003183            1.601233         0.000050
# 503906  1452128306  1.599333  0.003233            1.599333         0.000050
# 503907  1452128307  1.924267  0.003217            1.924267         0.000033
# 503908  1452128308  1.978200  0.003217            1.978200         0.000050
# 503909  1452128309  1.990950  0.003233            1.990950         0.000050
# 503910           \       NaN       NaN                 NaN              NaN
#
#         Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# ...

# %%
df.describe()
# Out:
#             use [kW]       gen [kW]  House overall [kW]  Dishwasher [kW]  \
# count  503910.000000  503910.000000       503910.000000    503910.000000
# mean        0.858962       0.076229            0.858962         0.031368
# std         1.058207       0.128428            1.058207         0.190951
# min         0.000000       0.000000            0.000000         0.000000
# 25%         0.367667       0.003367            0.367667         0.000000
# 50%         0.562333       0.004283            0.562333         0.000017
# 75%         0.970250       0.083917            0.970250         0.000233
# max        14.714567       0.613883           14.714567         1.401767
#
#        Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]    Fridge [kW]  \
# count   503910.000000   503910.000000     503910.000000  503910.000000
# mean         0.099210        0.136779          0.081287       0.063556
# std          0.169059        0.178631          0.104466       0.076199
# ...

# %%
df.isnull()
# Out:
#          time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0       False     False     False               False            False
# 1       False     False     False               False            False
# 2       False     False     False               False            False
# 3       False     False     False               False            False
# 4       False     False     False               False            False
# ...       ...       ...       ...                 ...              ...
# 503906  False     False     False               False            False
# 503907  False     False     False               False            False
# 503908  False     False     False               False            False
# 503909  False     False     False               False            False
# 503910  False      True      True                True             True
#
#         Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# ...

# %%
df.columns
# Out:
# Index(['time', 'use [kW]', 'gen [kW]', 'House overall [kW]', 'Dishwasher [kW]',
#        'Furnace 1 [kW]', 'Furnace 2 [kW]', 'Home office [kW]', 'Fridge [kW]',
#        'Wine cellar [kW]', 'Garage door [kW]', 'Kitchen 12 [kW]',
#        'Kitchen 14 [kW]', 'Kitchen 38 [kW]', 'Barn [kW]', 'Well [kW]',
#        'Microwave [kW]', 'Living room [kW]', 'Solar [kW]', 'temperature',
#        'icon', 'humidity', 'visibility', 'summary', 'apparentTemperature',
#        'pressure', 'windSpeed', 'cloudCover', 'windBearing', 'precipIntensity',
#        'dewPoint', 'precipProbability'],
#       dtype='object')

# %%
#Extracting unique values from summary column
df['summary'].unique()
# Out:
# array(['Clear', 'Mostly Cloudy', 'Overcast', 'Partly Cloudy', 'Drizzle',
#        'Light Rain', 'Rain', 'Light Snow', 'Flurries', 'Breezy', 'Snow',
#        'Rain and Breezy', 'Foggy', 'Breezy and Mostly Cloudy',
#        'Breezy and Partly Cloudy', 'Flurries and Breezy', 'Dry',
#        'Heavy Snow', nan], dtype=object)

# %%
#Extracting unique values from cloudCover column 
df['cloudCover'].unique()
# Out:
# array(['cloudCover', '0.75', '0', '1', '0.31', '0.44', '0.13', '0.19',
#        '0.25', '0.16', '0.21', '0.15', '0.14', '0.27', '0.28', '0.17',
#        '0.05', '0.1', '0.26', '0.29', '0.11', '0.09', '0.12', '0.06',
#        '0.02', '0.08', '0.04', '0.35', '0.22', '0.23', '0.54', '0.39',
#        '0.03', '0.07', '0.76', '0.62', '0.18', '0.79', '0.48', '0.24',
#        '0.57', 0.24, 1.0, 0.31, 0.28, 0.15, 0.41, 0.1, 0.12, 0.08, 0.09,
#        0.19, 0.04, 0.05, 0.29, 0.27, 0.35, 0.18, 0.06, 0.03, 0.11, 0.14,
#        0.25, 0.78, 0.0, 0.16, 0.21, 0.23, 0.17, 0.75, 0.26, 0.2, 0.76,
#        0.13, 0.77, 0.46, 0.07, 0.55, 0.02, 0.01, 0.51, 0.47, 0.5, 0.4,
#        0.3, 0.22, 0.43, 0.33, 0.6, 0.68, 0.66, 0.45, 0.34, 0.52, 0.67,
#        0.48, 0.49, 0.39, 0.37, 0.62, 0.36, 0.79, 0.61, 0.38, 0.42, 0.53,
#        0.63, 0.44, 0.54, 0.32, 0.56, 0.58, 0.72, 0.57, 0.73, 0.71, 0.64,
#        0.59, nan], dtype=object)

# %%
#Renaming columns to remove the '[kW]' suffix and combining related columns to calculate total energy consumption for 'Furnace' and 'Kitchen'.
df.columns = [i.replace(' [kW]', '') for i in df.columns]
df['Furnace'] = df[['Furnace 1','Furnace 2']].sum(axis=1)
df['Kitchen'] = df[['Kitchen 12','Kitchen 14','Kitchen 38']].sum(axis=1)

# %%
#Dropping unnecessary columns related to individual appliances and weather descriptions to simplify the DataFrame.
df.drop(['Furnace 1','Furnace 2','Kitchen 12','Kitchen 14','Kitchen 38','icon','summary'], axis=1, inplace=True)

# %%
#Filling missing values in the 'cloudCover' column using backward fill (bfill) and converting the column to float data type
df['cloudCover'].replace(['cloudCover'], method='bfill', inplace=True)
df['cloudCover'] = df['cloudCover'].astype('float')

# %%
df.head(2)
# Out:
#          time       use       gen  House overall  Dishwasher  Home office  \
# 0  1451624400  0.932833  0.003483       0.932833    0.000033     0.442633
# 1  1451624401  0.934333  0.003467       0.934333    0.000000     0.444067
#
#     Fridge  Wine cellar  Garage door     Barn  ...  apparentTemperature  \
# 0  0.12415     0.006983     0.013083  0.03135  ...                29.26
# 1  0.12400     0.006983     0.013117  0.03150  ...                29.26
#
#    pressure  windSpeed  cloudCover  windBearing  precipIntensity  dewPoint  \
# 0   1016.91       9.18        0.75        282.0              0.0      24.4
# 1   1016.91       9.18        0.75        282.0              0.0      24.4
#
#    precipProbability   Furnace   Kitchen
# 0                0.0  0.082617  0.000567
# 1                0.0  0.084533  0.000567
#
# [2 rows x 27 columns]

# %%
tmp_str = "Feature(attribute)     DataType"; print(tmp_str+"\n"+"-"*len(tmp_str))
print(df.dtypes)
# Out:
# Feature(attribute)     DataType
# -------------------------------
# time                    object
# use                    float64
# gen                    float64
# House overall          float64
# Dishwasher             float64
# Home office            float64
# Fridge                 float64
# Wine cellar            float64
# Garage door            float64
# Barn                   float64
# Well                   float64
# Microwave              float64
# Living room            float64
# Solar                  float64
# temperature            float64
# humidity               float64
# visibility             float64
# apparentTemperature    float64
# pressure               float64
# windSpeed              float64
# cloudCover             float64
# windBearing            float64
# precipIntensity        float64
# dewPoint               float64
# precipProbability      float64
# Furnace                float64
# Kitchen                float64
# dtype: object

# %%
np.r_[0:5, -5:0]
# Out:
# array([ 0,  1,  2,  3,  4, -5, -4, -3, -2, -1])

# %%
df.iloc[np.r_[0:5, -5:0]]
# Out:
#               time       use       gen  House overall  Dishwasher  \
# 0       1451624400  0.932833  0.003483       0.932833    0.000033
# 1       1451624401  0.934333  0.003467       0.934333    0.000000
# 2       1451624402  0.931817  0.003467       0.931817    0.000017
# 3       1451624403  1.022050  0.003483       1.022050    0.000017
# 4       1451624404  1.139400  0.003467       1.139400    0.000133
# 503906  1452128306  1.599333  0.003233       1.599333    0.000050
# 503907  1452128307  1.924267  0.003217       1.924267    0.000033
# 503908  1452128308  1.978200  0.003217       1.978200    0.000050
# 503909  1452128309  1.990950  0.003233       1.990950    0.000050
# 503910           \       NaN       NaN            NaN         NaN
#
#         Home office    Fridge  Wine cellar  Garage door      Barn  ...  \
# 0          0.442633  0.124150     0.006983     0.013083  0.031350  ...
# 1          0.444067  0.124000     0.006983     0.013117  0.031500  ...
# ...

# %%
df = df[0:-1] 
df.tail()
# Out:
#               time       use       gen  House overall  Dishwasher  \
# 503905  1452128305  1.601233  0.003183       1.601233    0.000050
# 503906  1452128306  1.599333  0.003233       1.599333    0.000050
# 503907  1452128307  1.924267  0.003217       1.924267    0.000033
# 503908  1452128308  1.978200  0.003217       1.978200    0.000050
# 503909  1452128309  1.990950  0.003233       1.990950    0.000050
#
#         Home office    Fridge  Wine cellar  Garage door      Barn  ...  \
# 503905     0.041783  0.005267     0.008667     0.013483  0.032283  ...
# 503906     0.041750  0.005233     0.008433     0.013433  0.032200  ...
# 503907     0.042033  0.004983     0.008467     0.012933  0.032283  ...
# 503908     0.042100  0.005333     0.008233     0.012817  0.032183  ...
# 503909     0.042100  0.004917     0.008133     0.012833  0.032167  ...
#
#         apparentTemperature  pressure  windSpeed  cloudCover  windBearing  \
# ...

# %%
df.shape
# Out:
# (503910, 27)

# %%
#Converting the 'time' column to datetime format
df['time'] = pd.to_datetime(df['time'], unit='s')
df['time'] = pd.DatetimeIndex(pd.date_range('2016-01-01 05:00', periods=len(df),  freq='min'))
df = df.set_index('time')
df.head(2)
# Out:
#                           use       gen  House overall  Dishwasher  \
# time
# 2016-01-01 05:00:00  0.932833  0.003483       0.932833    0.000033
# 2016-01-01 05:01:00  0.934333  0.003467       0.934333    0.000000
#
#                      Home office   Fridge  Wine cellar  Garage door     Barn  \
# time
# 2016-01-01 05:00:00     0.442633  0.12415     0.006983     0.013083  0.03135
# 2016-01-01 05:01:00     0.444067  0.12400     0.006983     0.013117  0.03150
#
#                          Well  ...  apparentTemperature  pressure  windSpeed  \
# time                           ...
# 2016-01-01 05:00:00  0.001017  ...                29.26   1016.91       9.18
# 2016-01-01 05:01:00  0.001017  ...                29.26   1016.91       9.18
#
#                      cloudCover  windBearing  precipIntensity  dewPoint  \
# time
# 2016-01-01 05:00:00        0.75        282.0              0.0      24.4
# 2016-01-01 05:01:00        0.75        282.0              0.0      24.4
#
# ...

# %%
#Generating a heatmap to visualize the correlation matrix of the first 15 columns 
fig = plt.subplots(figsize=(10, 8))
sns.heatmap(df[df.columns[0:15].tolist()].corr(), annot=True, fmt='.2f', vmin=-1.0, vmax=1.0, center=0)
plt.title('Energy Correlation', fontsize=12);

# %%
print(df['gen'].equals(df['Solar']))
print(df['use'].equals(df['House overall']))
# Out:
# True
# True

# %%
df.drop(['use', 'gen'], axis=1, inplace=True)

# %%
#Generating a heatmap to visualize the correlation matrix of weather-related columns 
fig = plt.subplots(figsize=(10, 8)) 
sns.heatmap(df[df.columns[13:].tolist()].corr(), annot=True, vmin=-1.0, vmax=1.0, center=0)
plt.title('Weather Correlazion', fontsize=14);

# %%
#Create subplots to visualize the daily mean temperature, apparent temperature, dew point, and humidity. 
#The first subplot shows temperature-related metrics, while the second subplot shows humidity.
ig, axes = plt.subplots(2,1, figsize=(10,5))
df[['temperature','apparentTemperature', 'dewPoint']].resample('D').mean().plot(ax=axes[0], grid=True)
df[['humidity']].resample('D').mean().plot(ax=axes[1], grid=True)
# Out:
# <Axes: xlabel='time'>

# %%
df['temperature'].plot(figsize=(25,5))
# Out:
# <Axes: xlabel='time'>

# %%
df['temperature'].resample(rule='D').mean().plot(figsize=(25,5))
# Out:
# <Axes: xlabel='time'>

# %%
df['Microwave'].resample("h").mean().iloc[:24].plot()
# Out:
# <Axes: xlabel='time'>

# %%
df.groupby(df.index.hour).mean()['Microwave'].plot(xticks=np.arange(25)).set(xlabel='Daily Hours', ylabel='Microwave Usage (kW)')
# Out:
# [Text(0.5, 0, 'Daily Hours'), Text(0, 0.5, 'Microwave Usage (kW)')]

# %%
#Plot daily mean values of first six columns
df[df.columns[0:6].tolist()].resample("D").mean().plot(subplots=True, layout=(-1, 3), figsize=(20, 8),
                                                                grid=True,rot=45);

# %%
#Plot daily mean values of remaining columns
df[df.columns[6:13].tolist()].resample("D").mean().plot(subplots=True, layout=(-1, 3), figsize=(20, 10),
                                                                grid=True, rot=45, xlabel=None);

# %%
df[df.columns[13:].tolist()].resample("D").mean().plot(subplots=True, layout=(-1, 3), figsize=(20, 12),
                                                                grid=True, rot=45, xlabel=None);

# %%
#Extract temporal features such as month, day, weekday, hour, and minute from the DataFrame index 
#Add them as new columns
df['month'] = df.index.month
df['day'] = df.index.day
df['weekday'] = df.index.day_name()
df['hour'] = df.index.hour
df['minute'] = df.index.minute
df.head(5)
# Out:
#                      House overall  Dishwasher  Home office    Fridge  \
# time
# 2016-01-01 05:00:00       0.932833    0.000033     0.442633  0.124150
# 2016-01-01 05:01:00       0.934333    0.000000     0.444067  0.124000
# 2016-01-01 05:02:00       0.931817    0.000017     0.446067  0.123533
# 2016-01-01 05:03:00       1.022050    0.000017     0.446583  0.123133
# 2016-01-01 05:04:00       1.139400    0.000133     0.446533  0.122850
#
#                      Wine cellar  Garage door      Barn      Well  Microwave  \
# time
# 2016-01-01 05:00:00     0.006983     0.013083  0.031350  0.001017   0.004067
# 2016-01-01 05:01:00     0.006983     0.013117  0.031500  0.001017   0.004067
# 2016-01-01 05:02:00     0.006983     0.013083  0.031517  0.001000   0.004067
# 2016-01-01 05:03:00     0.006983     0.013000  0.031500  0.001017   0.004067
# 2016-01-01 05:04:00     0.006850     0.012783  0.031500  0.001017   0.004067
#
#                      Living room  ...  precipIntensity  dewPoint  \
# ...

# %%
#Plot the mean values of energy consumption features grouped by month
mean_month = df.groupby('month').agg({i:'mean' for i in df.columns[:-5].tolist()})
mean_month[mean_month.columns[0:13].tolist()].plot(subplots=True, layout=(-1, 3), figsize=(15, 10),
                                                       grid=True, rot=45, xlabel=None, marker='o');

# %%
#Plot the mean values of energy consumption features grouped by weekday
days = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
mean_weekday = df.groupby('weekday').agg({i:'mean' for i in df.columns[:-5].tolist()}).reindex(days)

mean_weekday[mean_weekday.columns[0:13].tolist()].plot(subplots=True, layout=(-1, 3), figsize=(15, 10),
                                                       grid=True, rot=45, xlabel=None, marker='o');

# %%
#Plot the mean values of energy consumption features grouped by hour of the day
mean_hour = df.groupby('hour').agg({i:'mean' for i in df.columns[:-5].tolist()})

mean_hour[mean_hour.columns[0:13].tolist()].plot(subplots=True, layout=(-1, 3), figsize=(18, 12),
                                                       grid=True, rot=45, xlabel=None, marker='o');

# %%
#Calculate the correlation coefficients between energy consumption features and weather-related features
consumptions = df.columns[0:13].tolist()
weather = df.columns[13:-5].tolist()
lists = [consumptions,]
for j in weather:
    correlations = []
    for i in consumptions:
        cor = df[i].corr(df[j])
        correlations.append(cor)
    lists.append(correlations)

names=['consumptions']
for i in weather:
    names.append(i+'_corr')
dataframe_corr = pd.DataFrame(np.column_stack(lists), columns=names).set_index('consumptions')

for i in dataframe_corr.columns[:].tolist():
    dataframe_corr[i] = dataframe_corr[i].apply(float)

# %%
dataframe_corr.style.applymap(lambda x: "background-color: red" if x > 0.1 else "background-color: orange" if x < -0.1 else "background-color: white")
# Out:
# <style type="text/css">
# ...

# %%
#Visualize the daily mean energy consumption of the 'House overall' feature along with its rolling mean and rolling standard deviation 
data_daily = df['House overall'].resample('d').mean()
rollingMEAN = data_daily.rolling(window=10).mean()
rollingSTD = data_daily.rolling(window=10).std()

fig, (ax1, ax2) = plt.subplots(2,1,figsize=(16,6))
plt.subplots_adjust(hspace=0.4)
ax1.plot(data_daily, c='black',label='Data - House overall')
ax1.plot(rollingMEAN, c='red', label='Rolling mean')
ax2.plot(rollingSTD, c='blue',label = 'Rolling Std')

ax1.legend(fontsize=12), ax2.legend(fontsize=12)
ax1.set_ylabel('kW'), ax2.set_ylabel('kW')
ax1.margins(x=0), ax2.margins(x=0)
ax1.grid(), ax2.grid()
# Out:
# (None, None)

# %%
#Perform the Dickey-Fuller test on the daily mean energy consumption data to check for stationarity
from statsmodels.tsa.stattools import adfuller

resultDFtest = adfuller(data_daily, autolag='AIC')
Out = pd.Series(resultDFtest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key1, value1 in resultDFtest[4].items():
    Out['Critical Value (%s)'%key1] = value1
    
print('DICK-FULLER RESULTS: \n\n{}'.format(Out))
# Out:
# DICK-FULLER RESULTS:
#
# Test Statistic                  -2.988003
# p-value                          0.036030
# #Lags Used                      10.000000
# Number of Observations Used    340.000000
# Critical Value (1%)             -3.449730
# Critical Value (5%)             -2.870079
# Critical Value (10%)            -2.571319
# dtype: float64

# %%
#Calculate and visualize the autocorrelation and partial autocorrelation functions for the daily mean energy consumption data.

data_daily_diff = data_daily-data_daily.shift(1)
data_daily_diff = data_daily_diff.dropna()


from statsmodels.graphics.tsaplots import acf, pacf
ACF = acf(data_daily, nlags=15)
PACF = pacf(data_daily, nlags=15, method='ols') 
ACF1 = acf(data_daily_diff, nlags=15)
PACF1 = pacf(data_daily_diff, nlags=15, method='ols') 

def plots_corr(ax,func,dat,title):
    ax.plot(func)
    ax.axhline(y=0, linestyle='--',c='gray')
    ax.axhline(y=-1.96/np.sqrt(len(dat)),linestyle='--',c='gray')
    ax.axhline(y=1.96/np.sqrt(len(dat)),linestyle='--',c='gray')
    ax.grid()
    ax.set_title(title)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,figsize=(14,8))
plt.subplots_adjust(hspace=0.3)
plots_corr(ax1, ACF, data_daily,'Autocorrelation Function')
plots_corr(ax2, PACF, data_daily,'Partial autocorrelation Function')
plots_corr(ax3, ACF1, data_daily_diff,'Autocorrelation Function - Diff')
plots_corr(ax4, PACF1, data_daily_diff,'Partial autocorrelation Function - Diff')

# %%
#Split the daily mean energy consumption data into training and testing sets using a 70-30 split ratio 
size = int(len(data_daily)*0.7)
train = data_daily[:size]
test = data_daily[size:]
print('Number of points in series:', len(data_daily))
print('Number of points in train:', len(train))
print('Number of points in test:', len(test))
# Out:
# Number of points in series: 351
# Number of points in train: 245
# Number of points in test: 106

# %%
#Fit an ARIMA model to the training data 
#Print the Akaike information criterion (AIC) as a measure of the model's goodness-of-fit.
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train, order=(2,1,1))
#model = sm.tsa.statespace.SARIMAX(train, order=(2,1,1), seasonal_order=(5,0,1,12))
model_fit = model.fit()
print('Akaike information criterion: ', model_fit.aic)
# Out:
# Akaike information criterion:  258.4623694313938

# %%
#Plot the actual daily mean energy consumption data along with the predictions made by the ARIMA model 
#Print the summary of the fitted model
plt.figure(figsize=(15,4))
plt.plot(data_daily, c='blue',label='Data - House overall')
plt.plot(model_fit.predict(dynamic=False), c='black', label='model')
plt.legend()
plt.grid(), plt.margins(x=0);
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:          House overall   No. Observations:                  245
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -125.231
# Date:                Tue, 02 Apr 2024   AIC                            258.462
# Time:                        20:55:24   BIC                            272.451
# Sample:                    01-01-2016   HQIC                           264.096
#                          - 09-01-2016
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4590      0.051      9.051      0.000       0.360       0.558
# ar.L2          0.0999      0.037      2.667      0.008       0.026       0.173
# ma.L1         -0.9438      0.026    -35.670      0.000      -0.996      -0.892
# ...

# %%
#Visualize the diagnostics plots of the fitted ARIMA model to assess its goodness-of-fit and identify any patterns or anomalies.
model_fit.plot_diagnostics(figsize=(12,7))
plt.show()

# %%
#Plotting the training and testing data along with the model's predictions, forecasting, and confidence intervals
#Evaluate the model's performance using various metrics 
#MSE, RMSE, MAE, MAPE, MASE, and R-squared score
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
new_fit = model_fit.append(data_daily[size:size+1], refit=False)
forecast = model_fit.forecast(len(test))
confidence = model_fit.get_forecast(len(test)).conf_int(0.05)

plt.figure(figsize=(15,4))
plt.plot(train, c='black',label='train data')
plt.plot(model_fit.predict(dynamic=False), c='green', label='model')
plt.plot(test, c='blue',label='test data')
plt.plot(forecast, c='red', label='model')
plt.fill_between(confidence.index,confidence['lower House overall'],
                 confidence['upper House overall'], color='k', alpha=.15)
plt.legend()
plt.grid(), plt.margins(x=0);

print('MSE: %.3f' % (mean_squared_error(test, forecast)))
print('RMSE: %.3f' % np.sqrt(mean_squared_error(test, forecast)))

MAE = mean_absolute_error(test, forecast)
MAPE = np.mean(np.abs(forecast - test)/np.abs(test))
MASE = np.mean(np.abs(test - forecast))/(np.abs(np.diff(train)).sum()/(len(train)-1))

print('MAE: %.3f' % MAE)
print('MAPE: %.3f' %MAPE)
print('MASE: %.3f' %MASE)
print('R^2 score: %.3f' % r2_score(test, forecast))
# Out:
# MSE: 0.259
# RMSE: 0.509
# MAE: 0.463
# MAPE: 0.722
# MASE: 1.886
# R^2 score: -2.379
